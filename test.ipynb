# %%
import numpy as np

# %%
a = [   [ -1,2]   ,   [-3,4]   ,  [-5,6]  ]
a = np.array(a)
b = np.array([1,10])
c = 100
d= np.sum(a*b,axis=1)+c>120

# %%
print a
print
print b
# Out:
# [[-1  2]
#  [-3  4]
#  [-5  6]]
#
# [ 1 10]

# %%
d= np.array(d,dtype= int)
print d
# Out:
# [0 1 1]

# %%
print np.exp(d)
# Out:
# [ 1.          2.71828183  2.71828183]

# %%
e= np.dot(d,a)

# %%
print(e)
# Out:
# [-8 10]

# %% [markdown]
# $$\Sigma_a\Sigma_bf(a)*f(b)=\Sigma_af(a)*\Sigma_bf(b)$$
